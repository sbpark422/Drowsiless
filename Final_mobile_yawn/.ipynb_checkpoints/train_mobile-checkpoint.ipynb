# %%
import cv2
import os
from shutil import copyfile
import keras
from keras.preprocessing.image import ImageDataGenerator#, img_to_array, array_to_img
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten#, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

from keras.applications.mobilenet import MobileNet
from keras.applications.mobilenet import preprocess_input as mobilenet_preproc
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
tb_hist = TensorBoard(log_dir='./graphFinal', histogram_freq=0, write_graph=True, write_images=True)

n_features = 512

def preprocess_input(x):
    img = x[:,:,::-1]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img

def mobilenet_model():
    base_model = MobileNet(weights='imagenet', include_top=True, 
                     input_shape=(224, 224, 3))
    base_model.layers.pop()
    x = base_model.layers[-1].output
    x = Dense(512)(x)
    x = Flatten()(x)
    #n_classes = Dense(6)(x)
    n_classes = Dense(1)(x)
    model = Model(input = base_model.input, output = n_classes)
    #opt = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None)
    opt = keras.optimizers.Adam()
    model.compile(
        #loss='categorical_crossentropy',
        loss='mean_squared_error',
        optimizer=opt,
        metrics=['accuracy'])
    print(model.summary())
    return model

# %%
#shape_used = (100, 100)
shape_used = (224, 224)
epochs = 100   #200
batch_size = 32
n_patience = 30

traingen = ImageDataGenerator(
    preprocessing_function = mobilenet_preproc,
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    #zoom_range=[0.8,1.2],
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    zca_whitening=False)
            
train_generator = traingen.flow_from_directory(
    directory='train/',
    target_size=shape_used,
    batch_size=batch_size,
    #class_mode="categorical",
    class_mode='sparse',
    shuffle=True,
    seed=42)

validgen = ImageDataGenerator(
    preprocessing_function = mobilenet_preproc,
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    #zoom_range=[0.8,1.2],
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    zca_whitening=False)

valid_generator = validgen.flow_from_directory(
    directory='valid/',
    target_size=shape_used,
    batch_size=batch_size,
    #class_mode="categorical",
    class_mode='sparse',
    shuffle=True,
    seed=42)

testgen = ImageDataGenerator(
    preprocessing_function = mobilenet_preproc,
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    #zoom_range=[0.8,1.2],
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    zca_whitening=False)

test_generator = testgen.flow_from_directory(
    directory='test/',
    target_size=shape_used,
    batch_size=batch_size,
    #class_mode="categorical",
    class_mode='sparse',
    shuffle=True,
    seed=42)
# Out:
# Found 1082 images belonging to 2 classes.
# Found 239 images belonging to 2 classes.
# Found 235 images belonging to 2 classes.

# %%
#model = custom_model()
model = mobilenet_model()


checkpoint = ModelCheckpoint('mobilenetTrain_100_checkF.h5', monitor='val_loss',
                             verbose=1, save_best_only=True)
earlystop = EarlyStopping(monitor='val_loss', patience=n_patience, verbose=1)

hist = model.fit_generator(train_generator,
                    epochs=epochs,
                    validation_data=valid_generator,
                    workers=4,
                    callbacks=[earlystop,checkpoint,tb_hist])

model.save('models/mobileTrain_100F.h5')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("de..., inputs=Tensor("in...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 226, 226, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (Activation)      (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, 114, 114, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (Activation)  (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (Activation)  (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 114, 114, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, 58, 58, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 58, 58, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, 30, 30, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 30, 30, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (Activation) (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, 9, 9, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 1000)        1025000
# _________________________________________________________________
# act_softmax (Activation)     (None, 1, 1, 1000)        0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1, 512)         512512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,766,889
# Trainable params: 4,745,001
# Non-trainable params: 21,888
# _________________________________________________________________
# None
# Epoch 1/200
# 34/34 [==============================] - 9s 259ms/step - loss: 0.1476 - acc: 0.7918 - val_loss: 0.2087 - val_acc: 0.6402
#
# Epoch 00001: val_loss improved from inf to 0.20867, saving model to mobilenetTrain_100_checkF.h5
# Epoch 2/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0717 - acc: 0.9160 - val_loss: 0.3143 - val_acc: 0.6318
#
# Epoch 00002: val_loss did not improve from 0.20867
# Epoch 3/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0500 - acc: 0.9334 - val_loss: 0.1554 - val_acc: 0.8285
#
# Epoch 00003: val_loss improved from 0.20867 to 0.15544, saving model to mobilenetTrain_100_checkF.h5
# Epoch 4/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0414 - acc: 0.9467 - val_loss: 0.0632 - val_acc: 0.9331
#
# Epoch 00004: val_loss improved from 0.15544 to 0.06323, saving model to mobilenetTrain_100_checkF.h5
# Epoch 5/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0327 - acc: 0.9641 - val_loss: 0.0310 - val_acc: 0.9623
#
# Epoch 00005: val_loss improved from 0.06323 to 0.03103, saving model to mobilenetTrain_100_checkF.h5
# Epoch 6/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0429 - acc: 0.9538 - val_loss: 0.2093 - val_acc: 0.7699
#
# Epoch 00006: val_loss did not improve from 0.03103
# Epoch 7/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0439 - acc: 0.9531 - val_loss: 0.2908 - val_acc: 0.7155
#
# Epoch 00007: val_loss did not improve from 0.03103
# Epoch 8/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0431 - acc: 0.9511 - val_loss: 0.2001 - val_acc: 0.7741
#
# Epoch 00008: val_loss did not improve from 0.03103
# Epoch 9/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0381 - acc: 0.9373 - val_loss: 0.0371 - val_acc: 0.9623
#
# Epoch 00009: val_loss did not improve from 0.03103
# Epoch 10/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0308 - acc: 0.9614 - val_loss: 0.0738 - val_acc: 0.8996
#
# Epoch 00010: val_loss did not improve from 0.03103
# Epoch 11/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0228 - acc: 0.9706 - val_loss: 0.0132 - val_acc: 0.9874
#
# Epoch 00011: val_loss improved from 0.03103 to 0.01324, saving model to mobilenetTrain_100_checkF.h5
# Epoch 12/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0252 - acc: 0.9741 - val_loss: 0.0415 - val_acc: 0.9498
#
# Epoch 00012: val_loss did not improve from 0.01324
# Epoch 13/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0191 - acc: 0.9782 - val_loss: 0.0221 - val_acc: 0.9749
#
# Epoch 00013: val_loss did not improve from 0.01324
# Epoch 14/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0158 - acc: 0.9798 - val_loss: 0.0274 - val_acc: 0.9707
#
# Epoch 00014: val_loss did not improve from 0.01324
# Epoch 15/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0122 - acc: 0.9862 - val_loss: 0.0261 - val_acc: 0.9749
#
# Epoch 00015: val_loss did not improve from 0.01324
# Epoch 16/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0157 - acc: 0.9779 - val_loss: 0.0304 - val_acc: 0.9582
#
# Epoch 00016: val_loss did not improve from 0.01324
# Epoch 17/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0167 - acc: 0.9761 - val_loss: 0.0769 - val_acc: 0.8787
#
# Epoch 00017: val_loss did not improve from 0.01324
# Epoch 18/200
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0104 - acc: 0.9807 - val_loss: 0.0076 - val_acc: 0.9916
#
# Epoch 00018: val_loss improved from 0.01324 to 0.00758, saving model to mobilenetTrain_100_checkF.h5
# Epoch 19/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0106 - acc: 0.9880 - val_loss: 0.0063 - val_acc: 0.9916
#
# Epoch 00019: val_loss improved from 0.00758 to 0.00633, saving model to mobilenetTrain_100_checkF.h5
# Epoch 20/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0072 - acc: 0.9936 - val_loss: 0.0086 - val_acc: 0.9874
#
# Epoch 00020: val_loss did not improve from 0.00633
# Epoch 21/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0180 - acc: 0.9789 - val_loss: 0.0163 - val_acc: 0.9833
#
# Epoch 00021: val_loss did not improve from 0.00633
# Epoch 22/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0275 - acc: 0.9697 - val_loss: 0.0528 - val_acc: 0.9414
#
# Epoch 00022: val_loss did not improve from 0.00633
# Epoch 23/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0335 - acc: 0.9573 - val_loss: 0.0308 - val_acc: 0.9665
#
# Epoch 00023: val_loss did not improve from 0.00633
# Epoch 24/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0140 - acc: 0.9871 - val_loss: 0.0301 - val_acc: 0.9665
#
# Epoch 00024: val_loss did not improve from 0.00633
# Epoch 25/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0075 - acc: 0.9897 - val_loss: 0.0186 - val_acc: 0.9833
#
# Epoch 00025: val_loss did not improve from 0.00633
# Epoch 26/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0479 - acc: 0.9437 - val_loss: 0.1330 - val_acc: 0.8619
#
# Epoch 00026: val_loss did not improve from 0.00633
# Epoch 27/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0264 - acc: 0.9667 - val_loss: 0.0715 - val_acc: 0.9163
#
# Epoch 00027: val_loss did not improve from 0.00633
# Epoch 28/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0206 - acc: 0.9752 - val_loss: 0.0321 - val_acc: 0.9665
#
# Epoch 00028: val_loss did not improve from 0.00633
# Epoch 29/200
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0160 - acc: 0.9814 - val_loss: 0.0180 - val_acc: 0.9791
#
# Epoch 00029: val_loss did not improve from 0.00633
# Epoch 30/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0158 - acc: 0.9816 - val_loss: 0.0148 - val_acc: 0.9874
#
# Epoch 00030: val_loss did not improve from 0.00633
# Epoch 31/200
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0093 - acc: 0.9880 - val_loss: 0.0058 - val_acc: 0.9958
#
# Epoch 00031: val_loss improved from 0.00633 to 0.00580, saving model to mobilenetTrain_100_checkF.h5
# Epoch 32/200
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0071 - acc: 0.9908 - val_loss: 0.0048 - val_acc: 0.9958
#
# Epoch 00032: val_loss improved from 0.00580 to 0.00480, saving model to mobilenetTrain_100_checkF.h5
# Epoch 33/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0049 - acc: 0.9945 - val_loss: 3.0493e-04 - val_acc: 1.0000
#
# Epoch 00033: val_loss improved from 0.00480 to 0.00030, saving model to mobilenetTrain_100_checkF.h5
# Epoch 34/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0049 - acc: 0.9954 - val_loss: 0.0097 - val_acc: 0.9833
#
# Epoch 00034: val_loss did not improve from 0.00030
# Epoch 35/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0081 - acc: 0.9890 - val_loss: 0.0111 - val_acc: 0.9874
#
# Epoch 00035: val_loss did not improve from 0.00030
# Epoch 36/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0080 - acc: 0.9890 - val_loss: 0.0045 - val_acc: 0.9916
#
# Epoch 00036: val_loss did not improve from 0.00030
# Epoch 37/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0081 - acc: 0.9880 - val_loss: 0.0022 - val_acc: 0.9958
#
# Epoch 00037: val_loss did not improve from 0.00030
# Epoch 38/200
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0045 - acc: 0.9954 - val_loss: 0.0051 - val_acc: 0.9916
#
# Epoch 00038: val_loss did not improve from 0.00030
# Epoch 39/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0066 - acc: 0.9936 - val_loss: 0.0120 - val_acc: 0.9833
#
# Epoch 00039: val_loss did not improve from 0.00030
# Epoch 40/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0033 - acc: 0.9963 - val_loss: 0.0057 - val_acc: 0.9958
#
# Epoch 00040: val_loss did not improve from 0.00030
# Epoch 41/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0121 - acc: 0.9869 - val_loss: 0.0234 - val_acc: 0.9749
#
# Epoch 00041: val_loss did not improve from 0.00030
# Epoch 42/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0055 - acc: 0.9924 - val_loss: 0.0079 - val_acc: 0.9874
#
# Epoch 00042: val_loss did not improve from 0.00030
# Epoch 43/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0121 - acc: 0.9869 - val_loss: 0.0108 - val_acc: 0.9916
#
# Epoch 00043: val_loss did not improve from 0.00030
# Epoch 44/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0055 - acc: 0.9936 - val_loss: 0.0072 - val_acc: 0.9916
#
# Epoch 00044: val_loss did not improve from 0.00030
# Epoch 45/200
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0046 - acc: 0.9945 - val_loss: 5.3859e-04 - val_acc: 1.0000
#
# Epoch 00045: val_loss did not improve from 0.00030
# Epoch 46/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0062 - acc: 0.9926 - val_loss: 3.8816e-05 - val_acc: 1.0000
#
# Epoch 00046: val_loss improved from 0.00030 to 0.00004, saving model to mobilenetTrain_100_checkF.h5
# Epoch 47/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0046 - acc: 0.9945 - val_loss: 0.0064 - val_acc: 0.9916
#
# Epoch 00047: val_loss did not improve from 0.00004
# Epoch 48/200
# 34/34 [==============================] - 5s 139ms/step - loss: 0.0046 - acc: 0.9917 - val_loss: 0.0016 - val_acc: 1.0000
#
# Epoch 00048: val_loss did not improve from 0.00004
# Epoch 49/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0031 - acc: 0.9972 - val_loss: 9.1339e-04 - val_acc: 1.0000
#
# Epoch 00049: val_loss did not improve from 0.00004
# Epoch 50/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0019 - acc: 0.9972 - val_loss: 0.0083 - val_acc: 0.9916
#
# Epoch 00050: val_loss did not improve from 0.00004
# Epoch 51/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0047 - acc: 0.9954 - val_loss: 0.0038 - val_acc: 0.9958
#
# Epoch 00051: val_loss did not improve from 0.00004
# Epoch 52/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0022 - acc: 0.9972 - val_loss: 1.5193e-04 - val_acc: 1.0000
#
# Epoch 00052: val_loss did not improve from 0.00004
# Epoch 53/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0068 - acc: 0.9926 - val_loss: 0.0091 - val_acc: 0.9916
#
# Epoch 00053: val_loss did not improve from 0.00004
# Epoch 54/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0183 - acc: 0.9789 - val_loss: 0.0643 - val_acc: 0.9205
#
# Epoch 00054: val_loss did not improve from 0.00004
# Epoch 55/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0268 - acc: 0.9695 - val_loss: 0.0204 - val_acc: 0.9749
#
# Epoch 00055: val_loss did not improve from 0.00004
# Epoch 56/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0186 - acc: 0.9807 - val_loss: 0.1670 - val_acc: 0.6402
#
# Epoch 00056: val_loss did not improve from 0.00004
# Epoch 57/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0134 - acc: 0.9851 - val_loss: 0.1574 - val_acc: 0.6067
#
# Epoch 00057: val_loss did not improve from 0.00004
# Epoch 58/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0080 - acc: 0.9904 - val_loss: 0.0365 - val_acc: 0.8787
#
# Epoch 00058: val_loss did not improve from 0.00004
# Epoch 59/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0107 - acc: 0.9890 - val_loss: 0.0211 - val_acc: 0.9247
#
# Epoch 00059: val_loss did not improve from 0.00004
# Epoch 60/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0135 - acc: 0.9842 - val_loss: 0.0534 - val_acc: 0.8577
#
# Epoch 00060: val_loss did not improve from 0.00004
# Epoch 61/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0167 - acc: 0.9825 - val_loss: 0.0108 - val_acc: 0.9916
#
# Epoch 00061: val_loss did not improve from 0.00004
# Epoch 62/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0077 - acc: 0.9890 - val_loss: 3.3262e-04 - val_acc: 1.0000
#
# Epoch 00062: val_loss did not improve from 0.00004
# Epoch 63/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0046 - acc: 0.9952 - val_loss: 0.0014 - val_acc: 1.0000
#
# Epoch 00063: val_loss did not improve from 0.00004
# Epoch 64/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0050 - acc: 0.9936 - val_loss: 0.0095 - val_acc: 0.9874
#
# Epoch 00064: val_loss did not improve from 0.00004
# Epoch 65/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0040 - acc: 0.9954 - val_loss: 8.8003e-04 - val_acc: 1.0000
#
# Epoch 00065: val_loss did not improve from 0.00004
# Epoch 66/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0139 - acc: 0.9816 - val_loss: 0.0186 - val_acc: 0.9791
#
# Epoch 00066: val_loss did not improve from 0.00004
# Epoch 67/200
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0068 - acc: 0.9926 - val_loss: 0.0048 - val_acc: 0.9958
#
# Epoch 00067: val_loss did not improve from 0.00004
# Epoch 68/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0073 - acc: 0.9897 - val_loss: 0.0032 - val_acc: 0.9958
#
# Epoch 00068: val_loss did not improve from 0.00004
# Epoch 69/200
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0034 - acc: 0.9954 - val_loss: 0.0137 - val_acc: 0.9833
#
# Epoch 00069: val_loss did not improve from 0.00004
# Epoch 70/200
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0075 - acc: 0.9899 - val_loss: 0.0121 - val_acc: 0.9833
#
# Epoch 00070: val_loss did not improve from 0.00004
# Epoch 71/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0088 - acc: 0.9880 - val_loss: 0.0531 - val_acc: 0.9414
#
# Epoch 00071: val_loss did not improve from 0.00004
# Epoch 72/200
# 34/34 [==============================] - 5s 132ms/step - loss: 0.0140 - acc: 0.9816 - val_loss: 0.0123 - val_acc: 0.9833
#
# Epoch 00072: val_loss did not improve from 0.00004
# Epoch 73/200
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0107 - acc: 0.9871 - val_loss: 1.7888e-04 - val_acc: 1.0000
#
# Epoch 00073: val_loss did not improve from 0.00004
# Epoch 74/200
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0030 - acc: 0.9963 - val_loss: 2.7900e-04 - val_acc: 1.0000
#
# Epoch 00074: val_loss did not improve from 0.00004
# Epoch 75/200
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0054 - acc: 0.9945 - val_loss: 1.4110e-04 - val_acc: 1.0000
#
# Epoch 00075: val_loss did not improve from 0.00004
# Epoch 76/200
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0022 - acc: 0.9972 - val_loss: 3.6955e-04 - val_acc: 1.0000
#
# Epoch 00076: val_loss did not improve from 0.00004
# Epoch 00076: early stopping

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 0.5])

acc_ax.plot(hist.history['acc'], 'b', label='train acc')
acc_ax.plot(hist.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.8, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
scores = model.evaluate_generator(test_generator, steps=8)
print("## evaluation ##")
print(scores)
print("##  accuracy  ##")
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# ## evaluation ##
# [0.009708489494283988, 0.9914893617021276]
# ##  accuracy  ##
# acc: 99.15%
