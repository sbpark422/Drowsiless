# %%
import cv2
import os
from shutil import copyfile
import keras
from keras.preprocessing.image import ImageDataGenerator#, img_to_array, array_to_img
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten#, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.model_selection import train_test_split

from keras.applications.mobilenet import MobileNet
from keras.applications.mobilenet import preprocess_input as mobilenet_preproc
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:521: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:522: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
tb_hist = TensorBoard(log_dir='./graph', histogram_freq=0, write_graph=True, write_images=True)

n_features = 512

def preprocess_input(x):
    img = x[:,:,::-1]
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return img

def custom_model():              
    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',
                     input_shape=(shape_used[0], shape_used[1], 3)))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dense(n_features, activation='softmax'))
    model.add(Flatten())
    model.add(Dense(6, activation='softmax'))
    opt = keras.optimizers.Adam()
    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    print(model.summary())
    return model

def mobilenet_model():
    base_model = MobileNet(weights='imagenet', include_top=True, 
                     input_shape=(224, 224, 3))
    base_model.layers.pop()
    x = base_model.layers[-1].output
    x = Dense(512)(x)
    x = Flatten()(x)
    #n_classes = Dense(6)(x)
    n_classes = Dense(1)(x)
    model = Model(input = base_model.input, output = n_classes)
    #opt = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=None)
    opt = keras.optimizers.Adam()
    model.compile(
        #loss='categorical_crossentropy',
        loss='mean_squared_error',
        optimizer=opt,
        metrics=['accuracy'])
    print(model.summary())
    return model

# %%
#shape_used = (100, 100)
shape_used = (224, 224)
epochs = 300
batch_size = 32
n_patience = 30

traingen = ImageDataGenerator(
    preprocessing_function = mobilenet_preproc,
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    #zoom_range=[0.8,1.2],
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    zca_whitening=False)
            
train_generator = traingen.flow_from_directory(
    directory='train/',
    target_size=shape_used,
    batch_size=batch_size,
    #class_mode="categorical",
    class_mode='sparse',
    shuffle=True,
    seed=42)

validgen = ImageDataGenerator(
    preprocessing_function = mobilenet_preproc,
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    #zoom_range=[0.8,1.2],
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    zca_whitening=False)

valid_generator = validgen.flow_from_directory(
    directory='valid/',
    target_size=shape_used,
    batch_size=batch_size,
    #class_mode="categorical",
    class_mode='sparse',
    shuffle=True,
    seed=42)

testgen = ImageDataGenerator(
    preprocessing_function = mobilenet_preproc,
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    #zoom_range=[0.8,1.2],
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False,  # randomly flip images
    zca_whitening=False)

test_generator = testgen.flow_from_directory(
    directory='test/',
    target_size=shape_used,
    batch_size=batch_size,
    #class_mode="categorical",
    class_mode='sparse',
    shuffle=True,
    seed=42)
# Out:
# Found 1082 images belonging to 2 classes.
# Found 239 images belonging to 2 classes.
# Found 235 images belonging to 2 classes.

# %%
#model = custom_model()
model = mobilenet_model()


checkpoint = ModelCheckpoint('mobilenetTrain.h5', monitor='val_loss',
                             verbose=1, save_best_only=True)
earlystop = EarlyStopping(monitor='val_loss', patience=n_patience, verbose=1)

hist = model.fit_generator(train_generator,
                    epochs=epochs,
                    validation_data=valid_generator,
                    workers=4,
                    callbacks=[earlystop,checkpoint,tb_hist])

model.save('models/mobileTrain.h5')
# Out:
# Found 1082 images belonging to 2 classes.
# Found 239 images belonging to 2 classes.
# Found 235 images belonging to 2 classes.
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:42: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 226, 226, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (Activation)      (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pad_1 (ZeroPadding2D)   (None, 114, 114, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (Activation)  (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (Activation)  (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 114, 114, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (Activation)  (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_3 (ZeroPadding2D)   (None, 58, 58, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (Activation)  (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 58, 58, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (Activation)  (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_5 (ZeroPadding2D)   (None, 30, 30, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (Activation)  (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 30, 30, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (Activation)  (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_7 (ZeroPadding2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_8 (ZeroPadding2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_9 (ZeroPadding2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (Activation)  (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_10 (ZeroPadding2D)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_11 (ZeroPadding2D)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (Activation) (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 16, 16, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (Activation) (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pad_13 (ZeroPadding2D)  (None, 9, 9, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (Activation) (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 1000)        1025000
# _________________________________________________________________
# act_softmax (Activation)     (None, 1, 1, 1000)        0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1, 512)         512512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,766,889
# Trainable params: 4,745,001
# Non-trainable params: 21,888
# _________________________________________________________________
# None
# Epoch 1/300
# 34/34 [==============================] - 9s 257ms/step - loss: 0.1726 - acc: 0.7863 - val_loss: 0.1222 - val_acc: 0.8117
#
# Epoch 00001: val_loss improved from inf to 0.12221, saving model to mobilenetTrain.h5
# Epoch 2/300
# 34/34 [==============================] - 5s 139ms/step - loss: 0.0505 - acc: 0.9439 - val_loss: 0.1835 - val_acc: 0.8033
#
# Epoch 00002: val_loss did not improve from 0.12221
# Epoch 3/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0529 - acc: 0.9410 - val_loss: 0.1553 - val_acc: 0.7741
#
# Epoch 00003: val_loss did not improve from 0.12221
# Epoch 4/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0523 - acc: 0.9412 - val_loss: 0.0792 - val_acc: 0.9038
#
# Epoch 00004: val_loss improved from 0.12221 to 0.07923, saving model to mobilenetTrain.h5
# Epoch 5/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0346 - acc: 0.9593 - val_loss: 0.2688 - val_acc: 0.7071
#
# Epoch 00005: val_loss did not improve from 0.07923
# Epoch 6/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0380 - acc: 0.9591 - val_loss: 0.1179 - val_acc: 0.8661
#
# Epoch 00006: val_loss did not improve from 0.07923
# Epoch 7/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0362 - acc: 0.9586 - val_loss: 0.1948 - val_acc: 0.7448
#
# Epoch 00007: val_loss did not improve from 0.07923
# Epoch 8/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0333 - acc: 0.9647 - val_loss: 0.0165 - val_acc: 0.9833
#
# Epoch 00008: val_loss improved from 0.07923 to 0.01653, saving model to mobilenetTrain.h5
# Epoch 9/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0262 - acc: 0.9746 - val_loss: 0.0615 - val_acc: 0.9163
#
# Epoch 00009: val_loss did not improve from 0.01653
# Epoch 10/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0282 - acc: 0.9669 - val_loss: 0.0128 - val_acc: 0.9833
#
# Epoch 00010: val_loss improved from 0.01653 to 0.01282, saving model to mobilenetTrain.h5
# Epoch 11/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0154 - acc: 0.9798 - val_loss: 0.0340 - val_acc: 0.9498
#
# Epoch 00011: val_loss did not improve from 0.01282
# Epoch 12/300
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0083 - acc: 0.9899 - val_loss: 0.0363 - val_acc: 0.9372
#
# Epoch 00012: val_loss did not improve from 0.01282
# Epoch 13/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0192 - acc: 0.9789 - val_loss: 0.0490 - val_acc: 0.9414
#
# Epoch 00013: val_loss did not improve from 0.01282
# Epoch 14/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0194 - acc: 0.9796 - val_loss: 0.0673 - val_acc: 0.9289
#
# Epoch 00014: val_loss did not improve from 0.01282
# Epoch 15/300
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0145 - acc: 0.9835 - val_loss: 0.0442 - val_acc: 0.9331
#
# Epoch 00015: val_loss did not improve from 0.01282
# Epoch 16/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0344 - acc: 0.9584 - val_loss: 0.0395 - val_acc: 0.9540
#
# Epoch 00016: val_loss did not improve from 0.01282
# Epoch 17/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0196 - acc: 0.9789 - val_loss: 0.0253 - val_acc: 0.9749
#
# Epoch 00017: val_loss did not improve from 0.01282
# Epoch 18/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0172 - acc: 0.9796 - val_loss: 0.0584 - val_acc: 0.9372
#
# Epoch 00018: val_loss did not improve from 0.01282
# Epoch 19/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0161 - acc: 0.9816 - val_loss: 0.0320 - val_acc: 0.9623
#
# Epoch 00019: val_loss did not improve from 0.01282
# Epoch 20/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0181 - acc: 0.9807 - val_loss: 0.0384 - val_acc: 0.9540
#
# Epoch 00020: val_loss did not improve from 0.01282
# Epoch 21/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0148 - acc: 0.9816 - val_loss: 0.0284 - val_acc: 0.9623
#
# Epoch 00021: val_loss did not improve from 0.01282
# Epoch 22/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0132 - acc: 0.9844 - val_loss: 0.0166 - val_acc: 0.9749
#
# Epoch 00022: val_loss did not improve from 0.01282
# Epoch 23/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0144 - acc: 0.9842 - val_loss: 0.0168 - val_acc: 0.9791
#
# Epoch 00023: val_loss did not improve from 0.01282
# Epoch 24/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0105 - acc: 0.9862 - val_loss: 0.0046 - val_acc: 0.9958
#
# Epoch 00024: val_loss improved from 0.01282 to 0.00457, saving model to mobilenetTrain.h5
# Epoch 25/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0092 - acc: 0.9871 - val_loss: 0.0026 - val_acc: 0.9958
#
# Epoch 00025: val_loss improved from 0.00457 to 0.00264, saving model to mobilenetTrain.h5
# Epoch 26/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0037 - acc: 0.9954 - val_loss: 0.0074 - val_acc: 0.9874
#
# Epoch 00026: val_loss did not improve from 0.00264
# Epoch 27/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0055 - acc: 0.9936 - val_loss: 3.1534e-04 - val_acc: 1.0000
#
# Epoch 00027: val_loss improved from 0.00264 to 0.00032, saving model to mobilenetTrain.h5
# Epoch 28/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0062 - acc: 0.9932 - val_loss: 7.6058e-04 - val_acc: 1.0000
#
# Epoch 00028: val_loss did not improve from 0.00032
# Epoch 29/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0057 - acc: 0.9906 - val_loss: 3.7829e-04 - val_acc: 1.0000
#
# Epoch 00029: val_loss did not improve from 0.00032
# Epoch 30/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0074 - acc: 0.9936 - val_loss: 0.0042 - val_acc: 0.9958
#
# Epoch 00030: val_loss did not improve from 0.00032
# Epoch 31/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0065 - acc: 0.9908 - val_loss: 0.0237 - val_acc: 0.9749
#
# Epoch 00031: val_loss did not improve from 0.00032
# Epoch 32/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0107 - acc: 0.9890 - val_loss: 0.0100 - val_acc: 0.9833
#
# Epoch 00032: val_loss did not improve from 0.00032
# Epoch 33/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0170 - acc: 0.9825 - val_loss: 0.0157 - val_acc: 0.9833
#
# Epoch 00033: val_loss did not improve from 0.00032
# Epoch 34/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0163 - acc: 0.9825 - val_loss: 0.0111 - val_acc: 0.9874
#
# Epoch 00034: val_loss did not improve from 0.00032
# Epoch 35/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0202 - acc: 0.9770 - val_loss: 0.0448 - val_acc: 0.9582
#
# Epoch 00035: val_loss did not improve from 0.00032
# Epoch 36/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0204 - acc: 0.9779 - val_loss: 0.0173 - val_acc: 0.9791
#
# Epoch 00036: val_loss did not improve from 0.00032
# Epoch 37/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0191 - acc: 0.9779 - val_loss: 0.0333 - val_acc: 0.9623
#
# Epoch 00037: val_loss did not improve from 0.00032
# Epoch 38/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0210 - acc: 0.9750 - val_loss: 0.0287 - val_acc: 0.9623
#
# Epoch 00038: val_loss did not improve from 0.00032
# Epoch 39/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0167 - acc: 0.9807 - val_loss: 0.0116 - val_acc: 0.9833
#
# Epoch 00039: val_loss did not improve from 0.00032
# Epoch 40/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0132 - acc: 0.9844 - val_loss: 0.0225 - val_acc: 0.9749
#
# Epoch 00040: val_loss did not improve from 0.00032
# Epoch 41/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0176 - acc: 0.9823 - val_loss: 0.0134 - val_acc: 0.9874
#
# Epoch 00041: val_loss did not improve from 0.00032
# Epoch 42/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0109 - acc: 0.9899 - val_loss: 0.0067 - val_acc: 0.9916
#
# Epoch 00042: val_loss did not improve from 0.00032
# Epoch 43/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0199 - acc: 0.9770 - val_loss: 0.0831 - val_acc: 0.8870
# Epoch 00043: val_loss did not improve from 0.00032
# Epoch 44/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0331 - acc: 0.9623 - val_loss: 0.0174 - val_acc: 0.9833
#
# Epoch 00044: val_loss did not improve from 0.00032
# Epoch 45/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0169 - acc: 0.9798 - val_loss: 0.0115 - val_acc: 0.9833
#
# Epoch 00045: val_loss did not improve from 0.00032
# Epoch 46/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0105 - acc: 0.9871 - val_loss: 0.0044 - val_acc: 0.9958
#
# Epoch 00046: val_loss did not improve from 0.00032
# Epoch 47/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0112 - acc: 0.9880 - val_loss: 0.0050 - val_acc: 0.9958
#
# Epoch 00047: val_loss did not improve from 0.00032
# Epoch 48/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0078 - acc: 0.9926 - val_loss: 0.0045 - val_acc: 0.9958
#
# Epoch 00048: val_loss did not improve from 0.00032
# Epoch 49/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0117 - acc: 0.9849 - val_loss: 0.0075 - val_acc: 0.9874
#
# Epoch 00049: val_loss did not improve from 0.00032
# Epoch 50/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0109 - acc: 0.9880 - val_loss: 0.0093 - val_acc: 0.9916
#
# Epoch 00050: val_loss did not improve from 0.00032
# Epoch 51/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0112 - acc: 0.9880 - val_loss: 0.0066 - val_acc: 0.9916
#
# Epoch 00051: val_loss did not improve from 0.00032
# Epoch 52/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0048 - acc: 0.9954 - val_loss: 3.2854e-04 - val_acc: 1.0000
#
# Epoch 00052: val_loss did not improve from 0.00032
# Epoch 53/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0094 - acc: 0.9880 - val_loss: 0.0058 - val_acc: 0.9958
#
# Epoch 00053: val_loss did not improve from 0.00032
# Epoch 54/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0030 - acc: 0.9972 - val_loss: 1.9370e-04 - val_acc: 1.0000
#
# Epoch 00054: val_loss improved from 0.00032 to 0.00019, saving model to mobilenetTrain.h5
# Epoch 55/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0035 - acc: 0.9954 - val_loss: 0.0031 - val_acc: 0.9958
#
# Epoch 00055: val_loss did not improve from 0.00019
# Epoch 56/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0038 - acc: 0.9963 - val_loss: 0.0061 - val_acc: 0.9916
#
# Epoch 00056: val_loss did not improve from 0.00019
# Epoch 57/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0050 - acc: 0.9936 - val_loss: 3.1418e-04 - val_acc: 1.0000
#
# Epoch 00057: val_loss did not improve from 0.00019
# Epoch 58/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0054 - acc: 0.9945 - val_loss: 0.0100 - val_acc: 0.9874
#
# Epoch 00058: val_loss did not improve from 0.00019
# Epoch 59/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0167 - acc: 0.9798 - val_loss: 0.0116 - val_acc: 0.9833
#
# Epoch 00059: val_loss did not improve from 0.00019
# Epoch 60/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0066 - acc: 0.9917 - val_loss: 6.1835e-04 - val_acc: 1.0000
#
# Epoch 00060: val_loss did not improve from 0.00019
# Epoch 61/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0052 - acc: 0.9945 - val_loss: 0.0070 - val_acc: 0.9916
#
# Epoch 00061: val_loss did not improve from 0.00019
# Epoch 62/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0095 - acc: 0.9890 - val_loss: 0.0434 - val_acc: 0.9540
#
# Epoch 00062: val_loss did not improve from 0.00019
# Epoch 63/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0180 - acc: 0.9807 - val_loss: 0.0164 - val_acc: 0.9749
#
# Epoch 00063: val_loss did not improve from 0.00019
# Epoch 64/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0040 - acc: 0.9954 - val_loss: 0.0461 - val_acc: 0.8954
#
# Epoch 00064: val_loss did not improve from 0.00019
# Epoch 65/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0064 - acc: 0.9917 - val_loss: 0.0186 - val_acc: 0.9833
#
# Epoch 00065: val_loss did not improve from 0.00019
# Epoch 66/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0069 - acc: 0.9917 - val_loss: 0.0200 - val_acc: 0.9707
#
# Epoch 00066: val_loss did not improve from 0.00019
# Epoch 67/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0064 - acc: 0.9926 - val_loss: 0.0039 - val_acc: 0.9916
#
# Epoch 00067: val_loss did not improve from 0.00019
# Epoch 68/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0025 - acc: 0.9982 - val_loss: 0.0021 - val_acc: 1.0000
#
# Epoch 00068: val_loss did not improve from 0.00019
# Epoch 69/300
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0085 - acc: 0.9908 - val_loss: 0.0045 - val_acc: 0.9958
#
# Epoch 00069: val_loss did not improve from 0.00019
# Epoch 70/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0028 - acc: 0.9963 - val_loss: 2.8686e-04 - val_acc: 1.0000
#
# Epoch 00070: val_loss did not improve from 0.00019
# Epoch 71/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0031 - acc: 0.9963 - val_loss: 5.9452e-05 - val_acc: 1.0000
#
# Epoch 00071: val_loss improved from 0.00019 to 0.00006, saving model to mobilenetTrain.h5
# Epoch 72/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0025 - acc: 0.9972 - val_loss: 9.5576e-05 - val_acc: 1.0000
#
# Epoch 00072: val_loss did not improve from 0.00006
# Epoch 73/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0031 - acc: 0.9972 - val_loss: 3.6258e-04 - val_acc: 1.0000
#
# Epoch 00073: val_loss did not improve from 0.00006
# Epoch 74/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0012 - acc: 0.9991 - val_loss: 5.0767e-05 - val_acc: 1.0000
#
# Epoch 00074: val_loss improved from 0.00006 to 0.00005, saving model to mobilenetTrain.h5
# Epoch 75/300
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0034 - acc: 0.9963 - val_loss: 9.8544e-06 - val_acc: 1.0000
#
# Epoch 00075: val_loss improved from 0.00005 to 0.00001, saving model to mobilenetTrain.h5
# Epoch 76/300
# 34/34 [==============================] - 5s 136ms/step - loss: 0.0261 - acc: 0.9669 - val_loss: 0.2109 - val_acc: 0.7029
#
# Epoch 00076: val_loss did not improve from 0.00001
# Epoch 77/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0386 - acc: 0.9576 - val_loss: 0.2830 - val_acc: 0.6695
#
# Epoch 00077: val_loss did not improve from 0.00001
# Epoch 78/300
# 34/34 [==============================] - 5s 132ms/step - loss: 0.0198 - acc: 0.9787 - val_loss: 0.1246 - val_acc: 0.8243
#
# Epoch 00078: val_loss did not improve from 0.00001
# Epoch 79/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0087 - acc: 0.9906 - val_loss: 0.0280 - val_acc: 0.9623
#
# Epoch 00079: val_loss did not improve from 0.00001
# Epoch 80/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0064 - acc: 0.9915 - val_loss: 0.0071 - val_acc: 0.9916
#
# Epoch 00080: val_loss did not improve from 0.00001
# Epoch 81/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0167 - acc: 0.9825 - val_loss: 0.0250 - val_acc: 0.9749
#
# Epoch 00081: val_loss did not improve from 0.00001
# Epoch 82/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0094 - acc: 0.9862 - val_loss: 0.0100 - val_acc: 0.9916
#
# Epoch 00082: val_loss did not improve from 0.00001
# Epoch 83/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0071 - acc: 0.9915 - val_loss: 0.0115 - val_acc: 0.9874
#
# Epoch 00083: val_loss did not improve from 0.00001
# Epoch 84/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0045 - acc: 0.9954 - val_loss: 1.2173e-04 - val_acc: 1.0000
#
# Epoch 00084: val_loss did not improve from 0.00001
# Epoch 85/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0069 - acc: 0.9926 - val_loss: 0.0103 - val_acc: 0.9874
#
# Epoch 00085: val_loss did not improve from 0.00001
# Epoch 86/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0146 - acc: 0.9851 - val_loss: 0.0076 - val_acc: 0.9916
# Epoch 00086: val_loss did not improve from 0.00001
# Epoch 87/300
# 34/34 [==============================] - 5s 138ms/step - loss: 0.0110 - acc: 0.9880 - val_loss: 0.0080 - val_acc: 0.9874
#
# Epoch 00087: val_loss did not improve from 0.00001
# Epoch 88/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0080 - acc: 0.9926 - val_loss: 0.0191 - val_acc: 0.9833
#
# Epoch 00088: val_loss did not improve from 0.00001
# Epoch 89/300
# 34/34 [==============================] - 4s 131ms/step - loss: 0.0057 - acc: 0.9936 - val_loss: 0.0031 - val_acc: 1.0000
#
# Epoch 00089: val_loss did not improve from 0.00001
# Epoch 90/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0071 - acc: 0.9908 - val_loss: 0.0101 - val_acc: 0.9916
#
# Epoch 00090: val_loss did not improve from 0.00001
# Epoch 91/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0063 - acc: 0.9924 - val_loss: 0.0090 - val_acc: 0.9916
#
# Epoch 00091: val_loss did not improve from 0.00001
# Epoch 92/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0062 - acc: 0.9926 - val_loss: 0.0022 - val_acc: 1.0000
#
# Epoch 00092: val_loss did not improve from 0.00001
# Epoch 93/300
# 34/34 [==============================] - 5s 134ms/step - loss: 0.0059 - acc: 0.9917 - val_loss: 0.0076 - val_acc: 0.9874
#
# Epoch 00093: val_loss did not improve from 0.00001
# Epoch 94/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0047 - acc: 0.9954 - val_loss: 0.0080 - val_acc: 0.9916
#
# Epoch 00094: val_loss did not improve from 0.00001
# Epoch 95/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0031 - acc: 0.9972 - val_loss: 0.0324 - val_acc: 0.9665
#
# Epoch 00095: val_loss did not improve from 0.00001
# Epoch 96/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0043 - acc: 0.9954 - val_loss: 0.0134 - val_acc: 0.9833
#
# Epoch 00096: val_loss did not improve from 0.00001
# Epoch 97/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0029 - acc: 0.9963 - val_loss: 0.0066 - val_acc: 0.9916
#
# Epoch 00097: val_loss did not improve from 0.00001
# Epoch 98/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0061 - acc: 0.9926 - val_loss: 5.8467e-05 - val_acc: 1.0000
#
# Epoch 00098: val_loss did not improve from 0.00001
# Epoch 99/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0048 - acc: 0.9954 - val_loss: 0.0163 - val_acc: 0.9833
#
# Epoch 00099: val_loss did not improve from 0.00001
# Epoch 100/300
# 34/34 [==============================] - 5s 133ms/step - loss: 0.0034 - acc: 0.9963 - val_loss: 0.0015 - val_acc: 0.9958
#
# Epoch 00100: val_loss did not improve from 0.00001
# Epoch 101/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0032 - acc: 0.9963 - val_loss: 0.0041 - val_acc: 0.9958
#
# Epoch 00101: val_loss did not improve from 0.00001
# Epoch 102/300
# 34/34 [==============================] - 4s 132ms/step - loss: 0.0033 - acc: 0.9963 - val_loss: 9.3551e-05 - val_acc: 1.0000
#
# Epoch 00102: val_loss did not improve from 0.00001
# Epoch 103/300
# 34/34 [==============================] - 5s 135ms/step - loss: 0.0087 - acc: 0.9878 - val_loss: 0.0034 - val_acc: 0.9958
#
# Epoch 00103: val_loss did not improve from 0.00001
# Epoch 104/300
# 34/34 [==============================] - 5s 132ms/step - loss: 0.0059 - acc: 0.9945 - val_loss: 0.0030 - val_acc: 0.9958
#
# Epoch 00104: val_loss did not improve from 0.00001
# Epoch 105/300
# 34/34 [==============================] - 5s 137ms/step - loss: 0.0119 - acc: 0.9860 - val_loss: 0.0066 - val_acc: 0.9916
#
# Epoch 00105: val_loss did not improve from 0.00001
# Epoch 00105: early stopping

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()

acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(hist.history['val_loss'], 'r', label='val loss')
loss_ax.set_ylim([0.0, 0.5])

acc_ax.plot(hist.history['acc'], 'b', label='train acc')
acc_ax.plot(hist.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylim([0.8, 1.0])

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuray')

loss_ax.legend(loc='upper left')
acc_ax.legend(loc='lower left')

plt.show()

# %%
scores = model.evaluate_generator(test_generator, steps=8)
print("## evaluation ##")
print(scores)
print("#################")
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))
# Out:
# ## evaluation ##
# [0.015146609286510168, 0.9872340425531915]
# #################
# acc: 98.72%
